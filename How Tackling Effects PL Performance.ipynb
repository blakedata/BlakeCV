# %%
#Finding the rank of teams based on tackling
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt

# Load data from a CSV file into a Pandas DataFrame
dataFrame = pd.read_csv('C:\\Users\\118358981\\Downloads\\PLStats22.23 - Sheet1.csv')

# sorting  
dataFrame.sort_values("Tackles", inplace = True)
  
# creating a rank column and passing the returned rank series
# change method to 'min' to rank by minimum
dataFrame["Rank"] = dataFrame["Tackles"].rank(method ='min')
  
# display
dataFrame
# Out:
#               Squad  Tackles  Tackles Won  Tackles Lost  Tackles Won Def 3rd  \
# 12  Manchester City      355          207           148                  134
# 11        Liverpool      393          252           141                  170
# 14    Newcastle Utd      410          250           160                  186
# 18         West Ham      411          220           191                  197
# 0           Arsenal      412          255           157                  176
# 3         Brentford      417          241           176                  184
# 4          Brighton      426          235           191                  193
# 8            Fulham      430          241           189                  202
# 2       Bournemouth      442          269           173                  227
# 17        Tottenham      444          254           190                  234
# 15  Nott'ham Forest      450          272           178                  252
# 13   Manchester Utd      462          265           197                  254
# 1       Aston Villa      473          249           224                  235
# 10   Leicester City      488          297           191                  223
# 19           Wolves      513          290           223                  287
# 7           Everton      522          311           211                  273
# 6    Crystal Palace      523          313           210                  270
# 16      Southampton      538          311           227                  274
# 5           Chelsea      541          315           226                  264
# 9      Leeds United      614          359           255                  276
#
#     Tackles Won Mid 3rd  Tackles Won Att 3rd  Dribblers Tackled  \
# 12                  149                   72                161
# 11                  167                   56                180
# 14                  164                   60                206
# 18                  156                   58                174
# 0                   149                   87                179
# 3                   173                   60                177
# 4                   161                   72                171
# 8                   154                   74                196
# 2                   173                   42                183
# 17                  145                   65                187
# 15                  148                   50                201
# 13                  155                   53                210
# 1                   180                   58                221
# 10                  214                   51                225
# 19                  165                   61                213
# 7                   186                   63                219
# 6                   188                   65                213
# 16                  216                   48                224
# 5                   194                   83                237
# 9                   254                   84                298
#
#     Dribbler Tackles Lost  Blocks  ...  Losses  Goals For  Goals Against  \
# 12                    154     252  ...       4         67             25
# 11                    231     250  ...       8         47             29
# 14                    204     321  ...       3         39             19
# 18                    185     283  ...      14         24             34
# 0                     165     256  ...       3         66             26
# 3                     250     320  ...       5         43             34
# 4                     173     253  ...       7         46             31
# 8                     172     327  ...      10         38             37
# 2                     225     371  ...      15         25             54
# 17                    203     305  ...       9         52             40
# 15                    176     339  ...      13         22             49
# 13                    181     351  ...       6         41             35
# 1                     214     338  ...      11         35             39
# 10                    257     362  ...      16         38             47
# 19                    223     350  ...      15         22             41
# 7                     199     376  ...      14         22             40
# 6                     186     362  ...      13         22             38
# 16                    203     386  ...      17         23             46
# 5                     215     331  ...       9         29             28
# 9                     290     370  ...      13         35             44
#
#     Goal Difference  Points  Pts/MP  Attendance  \
# 12               42      61    2.26      53,219
# 11               18      42    1.62      53,197
# 14               20      47    1.81      52,241
# 18              -10      24    0.92      62,454
# 0                40      69    2.46      60,199
# 3                 9      42    1.56      17,071
# 4                15      42    1.68      31,457
# 8                 1      39    1.44      23,502
# 2               -29      24    0.89      10,371
# 17               12      49    1.75      61,654
# 15              -27      26    0.96      29,164
# 13                6      50    1.92      73,749
# 1                -4      38    1.41      41,634
# 10               -9      25    0.93      31,772
# 19              -19      27    0.96      31,583
# 7               -18      26    0.93      39,233
# 6               -16      27    0.96      24,882
# 16              -23      23    0.82      30,469
# 5                 1      38    1.41      39,973
# 9                -9      26    0.96      36,496
#
#                          Top Team Scorer         Goalkeeper  Rank
# 12                   Erling Haaland - 28            Ederson   1.0
# 11                    Mohamed Salah - 11            Alisson   2.0
# 14                   Miguel Almirón - 11          Nick Pope   3.0
# 18       Saïd Benrahma, Jarrod Bowen - 4   Łukasz Fabiański   4.0
# 0                        Martinelli - 13     Aaron Ramsdale   5.0
# 3                        Ivan Toney - 16         David Raya   6.0
# 4   Leandro Trossard, Solly March... - 7     Robert Sánchez   7.0
# 8               Aleksandar Mitrović - 11         Bernd Leno   8.0
# 2                     Philip Billing - 6               Neto   9.0
# 17                       Harry Kane - 21        Hugo Lloris  10.0
# 15                   Brennan Johnson - 7     Dean Henderson  11.0
# 13                  Marcus Rashford - 14       David de Gea  12.0
# 1                      Ollie Watkins - 9  Emiliano Martínez  13.0
# 10     James Maddison, Harvey Barnes - 9         Danny Ward  14.0
# 19       Rúben Neves, Daniel Podence - 5            José Sá  15.0
# 7                       Demarai Gray - 4    Jordan Pickford  16.0
# 6                      Wilfried Zaha - 6     Vicente Guaita  17.0
# 16                 James Ward-Prowse - 7       Gavin Bazunu  18.0
# 5                        Kai Havertz - 7  Kepa Arrizabalaga  19.0
# 9                           Rodrigo - 11      Illan Meslier  20.0
#
# [20 rows x 45 columns]

# %%
#Building on this to create a simple visualization

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt

sns.set_theme(style="whitegrid")

# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(6, 15))
# Load data from a CSV file into a Pandas DataFrame
dataFrame = pd.read_csv('C:\\Users\\118358981\\Downloads\\PLStats22.23 - Sheet1.csv').sort_values("Tackles", ascending=False)

  
# creating a rank column and passing the returned rank series
# change method to 'min' to rank by minimum
dataFrame["Rank"] = dataFrame["Tackles"].rank(method ='min')

# Plot 
sns.set_color_codes("pastel")
sns.barplot(x="Rank", y="Squad", data=dataFrame,
            label="Tackle Rank", color="b")


ax.set(xlim=(0, 20), ylabel="Squad",
       xlabel="Tackle Ranking by Team", )
# ax.bar_label(ax.containers[0])
sns.despine(left=True, bottom=True)

# %%
# Comparing tackles versus the variables of goals and wins by Team

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt

# Load data from a CSV file into a Pandas DataFrame
dataFrame = pd.read_csv('C:\\Users\\118358981\\Downloads\\PLStats22.23 - Sheet1.csv')

sns.set_theme(style="ticks")

chart = sns.pairplot(data=dataFrame, diag_kind="hist", hue="Squad", x_vars=["Tackles"], y_vars=["Wins", "Goals"])

# %%
# Another visualization to further understand the affect tackling has on team performance

import seaborn as sns
sns.set_theme(style="whitegrid")

# Load the example Titanic dataset
dataFrame = pd.read_csv('C:\\Users\\118358981\\Downloads\\PLStats22.23 - Sheet1.csv')

sns.set_theme(style="whitegrid")


# Plot 
g = sns.lmplot(
    data=dataFrame,
    x="Tackles", y="Goal Difference", hue="Squad",
    height=5
)

# Using more informative axis labels than are provided by default
g.set_axis_labels("Tackles", "Goal Difference")
